# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.utils import to_categorical
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19324\876508572.py in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from tensorflow.keras.datasets import mnist
#       4 from tensorflow.keras.models import Sequential
#       5 from tensorflow.keras.layers import Flatten, Dense
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train / 255.0
X_test = X_test / 255.0
X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %%
model = Sequential([
    Flatten(input_shape=(784,)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19324\3234025741.py in <module>
# ----> 1 model = Sequential([
#       2     Flatten(input_shape=(784,)),
#       3     Dense(128, activation='relu'),
#       4     Dense(10, activation='softmax')
#       5 ])
#
# NameError: name 'Sequential' is not defined

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19324\2784023442.py in <module>
# ----> 1 test_loss, test_accuracy = model.evaluate(X_test, y_test)
#       2 print(f"Test accuracy: {test_accuracy}")
#
# NameError: name 'model' is not defined

# %%
predictions = model.predict(X_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
num_images = 10
for i in range(num_images):
    plt.imshow(X_test[i].reshape(28, 28), cmap='gray')
    predicted_label = np.argmax(predictions[i])
    true_label = np.argmax(y_test[i])
    plt.title(f"Predicted: {predicted_label}, True: {true_label}")
    plt.show()
